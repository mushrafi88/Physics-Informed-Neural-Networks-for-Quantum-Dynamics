# %%
import torch
import torch.nn as nn
import torch.nn.init as init
from torch.optim import AdamW, LBFGS
from torch.autograd import Variable
from tqdm import tqdm
import numpy as np
import os
import pandas as pd
from itertools import cycle 

import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
def fourier_features(x, B):
    x_transformed = torch.matmul(x, B)
    return torch.cat([torch.sin(x_transformed), torch.cos(x_transformed)], dim=-1)

def init_fixed_frequency_matrix(size, scale=1.0):
    num_elements = size[0] * size[1]
    lin_space = torch.linspace(-scale, scale, steps=num_elements)
    B = lin_space.view(size).float()
    return B

class FourierFeatureNN(nn.Module):
    def __init__(self, input_dim=1, shared_units=16, neuron_units=32, scale=1.0, 
                 activation=nn.Tanh, device='cpu'):
        super(FourierFeatureNN, self).__init__()
        self.Bx = init_fixed_frequency_matrix((input_dim, shared_units // 2), scale=scale).to(device)
        self.Bt = init_fixed_frequency_matrix((input_dim, shared_units // 2), scale=scale).to(device)

        # Define separate paths for x and t after Fourier transformation
        self.path_x = nn.Sequential( 
            nn.Linear(shared_units, neuron_units),  # Adjusted from shared_units // 2 to shared_units
            activation(),
            nn.Linear(neuron_units, neuron_units),
            activation(),
            nn.Linear(neuron_units, neuron_units),
            activation() )
        self.path_t = nn.Sequential( 
            nn.Linear(shared_units, neuron_units),  # Same adjustment
            activation(),
            nn.Linear(neuron_units, neuron_units),
            activation(),
            nn.Linear(neuron_units, neuron_units),
            activation() )

        # Define separate FFN for u and v directly after the paths
        self.ffn_u = nn.Sequential(
            nn.Linear(neuron_units, neuron_units), activation(),
            nn.Linear(neuron_units, neuron_units), activation(),
            nn.Linear(neuron_units, 2)  # Outputs for u (real and imaginary parts)
        )
        self.ffn_v = nn.Sequential(
            nn.Linear(neuron_units, neuron_units), activation(),
            nn.Linear(neuron_units, neuron_units), activation(),
            nn.Linear(neuron_units, 1)  # Output for v
        )

        self.apply(self.initialize_weights)

    def forward(self, x, t):
        # Apply Fourier feature transformations
        x_fourier = fourier_features(x, self.Bx)
        t_fourier = fourier_features(t, self.Bt)

        # Pass through separate paths
        x_path_output = self.path_x(x_fourier)
        t_path_output = self.path_t(t_fourier)

        # Pointwise multiplication of the separate path outputs
        combined_features = x_path_output * t_path_output

        # Directly pass through different FFNs for u and v
        final_output_u = self.ffn_u(combined_features)
        final_output_v = self.ffn_v(combined_features)

        # Splitting the output for u into real and complex parts
        output_1, output_2 = final_output_u.split(1, dim=-1)
        output_3 = final_output_v
        
        return output_1, output_2, output_3

    def initialize_weights(self, m):
        if isinstance(m, nn.Linear):
            init.xavier_uniform_(m.weight)
            if m.bias is not None:
                init.constant_(m.bias, 0)

# %%
def real_u1(x, t, k, omega, r):
    complex_exp = torch.exp(1j * r * (omega * x + t))
    tanh_val = torch.tanh((r * (k + x + omega * t)) / torch.sqrt(torch.tensor(2.0)))
    result = torch.real(1j * r * complex_exp * torch.sqrt(torch.tensor(1) + omega**2) * tanh_val)
    return result

def imag_u1(x, t, k, omega, r):
    complex_exp = torch.exp(1j * r * (omega * x + t))
    tanh_val = torch.tanh((r * (k + x + omega * t)) / torch.sqrt(torch.tensor(2.0)))
    result = torch.imag(1j * r * complex_exp * torch.sqrt(torch.tensor(1) + omega**2) * tanh_val)
    return result

def real_v1(x, t, k, omega, r):
    result = (r * torch.tanh((r * (k + x + omega * t)) / torch.sqrt(torch.tensor(2.0))))**2
    return result

def compute_analytical_boundary_loss(model, x, t, mse_cost_function, k, omega, r):
    pred_u_r, pred_u_i, pred_v = model(x, t)

    real_u1_val = real_u1(x, t, k, omega, r)
    imag_u1_val = imag_u1(x, t, k, omega, r)
    real_v1_val = real_v1(x, t, k, omega, r)
 
    boundary_loss_ur = mse_cost_function(pred_u_r, real_u1_val)
    boundary_loss_ui = mse_cost_function(pred_u_i, imag_u1_val)
    boundary_loss_v = mse_cost_function(pred_v, real_v1_val)
    
    return boundary_loss_ur, boundary_loss_ui, boundary_loss_v

def cyclic_iterator(items):
    return cycle(items)

# %%
def LBFGS_training(model, model_save_path, mse_cost_function, device, num_epochs, lr, num_samples, r, k, omega, gamma, beta, line_search_fn):
    print('Starting LBFGS Fine Tuning')
    optimizer = LBFGS(model.parameters(), lr=1, max_iter=20, max_eval=None, tolerance_grad=1e-07, tolerance_change=1e-09, history_size=100, line_search_fn=line_search_fn)
    factor = -2

    x_n = (torch.rand(num_samples, 1)*4 + factor ).to(device)  # x in range [-5, -3]
    t_n = (torch.rand(num_samples, 1)).to(device)   
    x_dom = (torch.rand(num_samples, 1)*4 + factor ).to(device)
    t_dom = torch.rand(num_samples, 1).to(device) 
    x_bc_x0 = (torch.zeros(num_samples, 1)*4 + factor ).to(device)
    t_bc_x0 = torch.rand(num_samples, 1).to(device)  # Uniformly distributed random values between 0 and 1
    x_bc_x1 = (torch.zeros(num_samples, 1)*4 - factor ).to(device)
    t_bc_x1 = torch.rand(num_samples, 1).to(device)  # Uniformly distributed random values between 0 and 1
    x_bc_t0 = (torch.rand(num_samples, 1)*4 + factor ).to(device)  # Uniformly distributed random values between 0 and 1
    t_bc_t0 = torch.zeros(num_samples, 1).to(device)


    for epoch in tqdm(range(num_epochs),
                  desc='Progress:',  
                  leave=False,  
                  ncols=75,
                  mininterval=0.1,
                  bar_format='{l_bar} {bar} | {remaining}',  # Only show the bar without any counters
                  colour='blue'): 
        model.train()
        
        def closure():
            optimizer.zero_grad()
            x_dom = (torch.rand(num_samples, 1)*4 + factor ).to(device)
            t_dom = torch.rand(num_samples, 1).to(device) 
            x_dom.requires_grad_(True)
            t_dom.requires_grad_(True)

            #physics_loss_ur, physics_loss_ui, physics_loss_v = compute_physics_loss(model, x_n, t_n, device, mse_cost_function) 
            u_real, u_imag, v = model(x_dom, t_dom)
            u_abs = torch.square(u_real) + torch.square(u_imag)

            # First order derivatives with retain_graph=True to reuse computational graph
            u_real_x = torch.autograd.grad(u_real.sum(), x_dom, create_graph=True, retain_graph=True)[0]
            u_real_t = torch.autograd.grad(u_real.sum(), t_dom, create_graph=True, retain_graph=True)[0]
            u_imag_x = torch.autograd.grad(u_imag.sum(), x_dom, create_graph=True, retain_graph=True)[0]
            u_imag_t = torch.autograd.grad(u_imag.sum(), t_dom, create_graph=True, retain_graph=True)[0]
            v_x = torch.autograd.grad(v.sum(), x_dom, create_graph=True, retain_graph=True)[0]
            v_t = torch.autograd.grad(v.sum(), t_dom, create_graph=True, retain_graph=True)[0]
    
            # Second order derivatives
            u_real_xx = torch.autograd.grad(u_real_x.sum(), x_dom, create_graph=True, retain_graph=True)[0]
            u_real_tt = torch.autograd.grad(u_real_t.sum(), t_dom, create_graph=True, retain_graph=True)[0]
            u_imag_xx = torch.autograd.grad(u_imag_x.sum(), x_dom, create_graph=True, retain_graph=True)[0]
            u_imag_tt = torch.autograd.grad(u_imag_t.sum(), t_dom, create_graph=True, retain_graph=True)[0]
            v_xx = torch.autograd.grad(v_x.sum(), x_dom, create_graph=True, retain_graph=True)[0]
            v_tt = torch.autograd.grad(v_t.sum(), t_dom, create_graph=True, retain_graph=True)[0]

            # Compute u_abs_xx with retain_graph if further gradients need to be calculated
            u_abs_x = torch.autograd.grad(u_abs.sum(), x_dom, create_graph=True, retain_graph=True)[0]
            u_abs_xx = torch.autograd.grad(u_abs_x.sum(), x_dom, create_graph=True, retain_graph=True)[0]

            # Define du_r, du_i, dv according to given formulas
            du_r = u_real_tt - u_real_xx + u_abs * u_real - 2 * u_real * v
            du_i = u_imag_tt - u_imag_xx + u_abs * u_imag - 2 * u_imag * v
            dv = v_tt + v_xx - u_abs_xx

            zero_target = torch.zeros_like(du_r)  # Assuming du_r, du_i, dv have the same shape
            physics_loss_ur = mse_cost_function(du_r, zero_target)
            physics_loss_ui = mse_cost_function(du_i, zero_target)
            physics_loss_v = mse_cost_function(dv, zero_target)
            print(physics_loss_ur)
            print(physics_loss_ur)
            print(physics_loss_v)

            boundary_loss_ur_x0, boundary_loss_ui_x0, boundary_loss_v_x0 = compute_analytical_boundary_loss(model, x_bc_x0, t_bc_x0, mse_cost_function, k, omega, r)
            boundary_loss_ur_x1, boundary_loss_ui_x1, boundary_loss_v_x1 = compute_analytical_boundary_loss(model, x_bc_x1, t_bc_x1, mse_cost_function, k, omega, r)
            boundary_loss_ur_t0, boundary_loss_ui_t0, boundary_loss_v_t0 = compute_analytical_boundary_loss(model, x_bc_t0, t_bc_t0, mse_cost_function, k, omega, r)
            # boundary_loss_ur_t1, boundary_loss_ui_t1, boundary_loss_v_t1 = compute_analytical_boundary_loss(model, x_bc_t1, t_bc_t1, mse_cost_function, k, omega, r)
            domain_loss_ur_t, domain_loss_ui_t, domain_loss_v_t = compute_analytical_boundary_loss(model, x_dom, t_dom, mse_cost_function, k, omega, r)
            
            # Total loss 
            loss_ur = gamma*(physics_loss_ur) + beta*( boundary_loss_ur_x0 + boundary_loss_ur_t0 )
            loss_ui = gamma*(physics_loss_ui) + beta*( boundary_loss_ui_x0 + boundary_loss_ui_t0 )
            loss_v = gamma*(physics_loss_v) + beta*( boundary_loss_v_x0 + boundary_loss_v_t0 )
            total_loss = loss_ur + loss_ui + loss_v
            total_loss.backward()

            return total_loss 
    
        optimizer.step(closure)
        if epoch % 10 == 0:
            current_loss = closure()  # Optionally recompute to print
            print(f' Epoch {epoch}, Loss: {current_loss.item()}') 
            model_filename = os.path.join(model_save_path, f'C_HIGGS_second_training_epoch_{epoch}.pth')
            torch.save(model.state_dict(), model_filename)
            plot_model_results(epoch, model, device, k, omega, r, sigma=1, cmap='viridis', image_save_path='results') 
            
    model_filename = os.path.join(model_save_path, f'C_HIGGS_second_training.pth')
    torch.save(model.state_dict(), model_filename)
    print('TRAINING COMPLETED')

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.ndimage import gaussian_filter

def plot_model_results(epoch, model, device, k, omega, r, sigma=1, cmap='viridis', image_save_path='results'):
    x = torch.linspace(-1.8, 1.8, 400)
    t = torch.linspace(0.2, 0.8, 400)
    X, T = torch.meshgrid(x, t)  # Create a 2D grid of x and t
    X_flat = X.flatten().unsqueeze(-1).to(device)
    T_flat = T.flatten().unsqueeze(-1).to(device)
    
    model_save_path = 'model_weights' 
    model_state = torch.load(os.path.join(model_save_path, f'C_HIGGS_second_training_epoch_{epoch}.pth'), map_location=device)
    model.load_state_dict(model_state)
    model.eval()

    # Get predictions from the trained models
    with torch.no_grad():
        pred_u_r, pred_u_i, pred_v = model(X_flat, T_flat) 

    pred_u_r = pred_u_r.cpu().reshape(X.shape).numpy()
    pred_u_i = pred_u_i.cpu().reshape(X.shape).numpy()
    pred_v = pred_v.cpu().reshape(X.shape).numpy()

    real_u1_analytical = real_u1(X_flat, T_flat, k, omega, r).cpu().reshape(X.shape).numpy()
    imag_u1_analytical = imag_u1(X_flat, T_flat, k, omega, r).cpu().reshape(X.shape).numpy()
    real_v1_analytical = real_v1(X_flat, T_flat, k, omega, r).cpu().reshape(X.shape).numpy()

    pred_v_smooth = gaussian_filter(pred_v, sigma=sigma)

    shrink = 0.3
    aspect = 50

    # Plotting predictions
    fig = plt.figure(figsize=(24, 16))

    ax1 = fig.add_subplot(231, projection='3d')
    ax1.plot_surface(X.numpy(), T.numpy(), pred_u_r, cmap=cmap)
    ax1.set_title('Predicted Real Part of $u_1(x, t)$')
    ax1.set_xlabel('x')
    ax1.set_ylabel('t')
    ax1.set_zlabel('Real part of $u_1$')

    ax2 = fig.add_subplot(232, projection='3d')
    ax2.plot_surface(X.numpy(), T.numpy(), pred_u_i, cmap=cmap)
    ax2.set_title('Predicted Imaginary Part of $u_1(x, t)$')
    ax2.set_xlabel('x')
    ax2.set_ylabel('t')
    ax2.set_zlabel('Imag part of $u_1$')

    ax3 = fig.add_subplot(233, projection='3d')
    ax3.plot_surface(X.numpy(), T.numpy(), pred_v_smooth, cmap=cmap)
    ax3.set_title('Predicted Real Part of $v_1(x, t)$')
    ax3.set_xlabel('x')
    ax3.set_ylabel('t')
    ax3.set_zlabel('Real part of $v_1$')

    ax4 = fig.add_subplot(234, projection='3d')
    ax4.plot_surface(X.numpy(), T.numpy(), real_u1_analytical, cmap=cmap)
    ax4.set_title('Analytical Real Part of $u_1(x, t)$')
    ax4.set_xlabel('x')
    ax4.set_ylabel('t')
    ax4.set_zlabel('Real part of $u_1$')

    ax5 = fig.add_subplot(235, projection='3d')
    ax5.plot_surface(X.numpy(), T.numpy(), imag_u1_analytical, cmap=cmap)
    ax5.set_title('Analytical Imaginary Part of $u_1(x, t)$')
    ax5.set_xlabel('x')
    ax5.set_ylabel('t')
    ax5.set_zlabel('Imag part of $u_1$')

    ax6 = fig.add_subplot(236, projection='3d')
    ax6.plot_surface(X.numpy(), T.numpy(), real_v1_analytical, cmap=cmap)
    ax6.set_title('Analytical Real Part of $v_1(x, t)$')
    ax6.set_xlabel('x')
    ax6.set_ylabel('t')
    ax6.set_zlabel('Real part of $v_1$')

    plt.tight_layout()
    plt.savefig(os.path.join(image_save_path, f'chiggs_model_comparison_3d_epoch_{epoch}.png'))
    plt.close(fig)  # Close the figure to free memory

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

if torch.cuda.is_available():
    print("CUDA is available! Training on GPU.")
else:
    print("CUDA is not available. Training on CPU.")

model = FourierFeatureNN(device=device).to(device)

print(model)
num_epochs_lbfgs = 500  # Number of training epochs
num_samples_lbfgs = 1000*3 # Number of samples for training
num_epochs_sq = 36000
num_samples_sq = 1000
lr_sq = 1e-4 
lr_lbfgs = 1e-3
r = 1.1
omega = 5 
k = 0.5
gamma = 1e-3
beta = 1
model_save_path = 'model_weights' 
mse_cost_function = torch.nn.MSELoss()
os.makedirs(model_save_path, exist_ok=True)
losses = []
line_search_fn = "strong_wolfe"
# Out:
# CUDA is available! Training on GPU.
# FourierFeatureNN(
#   (path_x): Sequential(
#     (0): Linear(in_features=16, out_features=32, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=32, out_features=32, bias=True)
#     (5): Tanh()
#   )
#   (path_t): Sequential(
#     (0): Linear(in_features=16, out_features=32, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=32, out_features=32, bias=True)
#     (5): Tanh()
#   )
#   (ffn_u): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=32, out_features=2, bias=True)
#   )
#   (ffn_v): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
LBFGS_training(model, model_save_path, mse_cost_function, device, num_epochs_lbfgs, lr_lbfgs, num_samples_lbfgs, r, k, omega, gamma, beta, line_search_fn)
# Out:
# Starting LBFGS Fine Tuning
# Progress::   0%|                                                        | ?
# tensor(0.0129, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0129, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0437, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0134, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0134, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0450, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0597, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0597, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0788, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(3.5893, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(3.5893, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1.4607, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.4720, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.4720, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.7627, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.3614, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.3614, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.7118, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1.1700, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1.1700, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1.8965, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(94.3099, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(94.3099, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(27.1607, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1141.8788, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1141.8788, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(401.9345, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(172.3550, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(172.3550, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(45.9670, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(86.3067, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(86.3067, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(26.3022, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(125.3401, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(125.3401, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(30.3481, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(174.4293, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(174.4293, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(33.3253, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(202.9064, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(202.9064, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(40.9138, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(140.0989, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(140.0989, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(100.0105, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(211.3857, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(211.3857, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(79.0880, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(170.1658, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(170.1658, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(81.4512, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(68.1021, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(68.1021, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(175.1995, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(115.8984, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(115.8984, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(128.9855, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(132.2652, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(132.2652, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(176.5600, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(298.4827, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(298.4827, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(504.4069, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(257.1309, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(257.1309, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(470.0700, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(234.6997, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(234.6997, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(608.4597, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(244.5753, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(244.5753, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(569.0911, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(238.7160, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(238.7160, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(563.0205, device='cuda:0', grad_fn=<MseLossBackward0>)
#  Epoch 0, Loss: 12.654170989990234
# Progress::   0%|                                                  | 1:17:19
# tensor(251.9633, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(251.9633, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(538.4986, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(238.4329, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(238.4329, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(791.0112, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(223.6780, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(223.6780, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(536.3262, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(261.6178, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(261.6178, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(812.5723, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(229.8281, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(229.8281, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(435.1586, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(251.0191, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(251.0191, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(508.9504, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(258.5945, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(258.5945, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(507.2711, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(226.9777, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(226.9777, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(529.5732, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(205.2485, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(205.2485, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(596.7529, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(233.4550, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(233.4550, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(573.2070, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(248.7646, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(248.7646, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(596.8429, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(299.4773, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(299.4773, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(823.9550, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(224.7550, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(224.7550, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(583.2688, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(255.2380, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(255.2380, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(553.7977, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(233.5099, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(233.5099, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(608.5798, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(243.9547, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(243.9547, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(651.9496, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(263.9020, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(263.9020, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(657.3140, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(260.5663, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(260.5663, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(740.7831, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(276.2812, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(276.2812, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(740.7069, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(251.9969, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(251.9969, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(855.3627, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(268.8382, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(268.8382, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(865.3892, device='cuda:0', grad_fn=<MseLossBackward0>)
# Progress::   0%| ▏                                                  | 44:12
# tensor(246.0305, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(246.0305, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(740.5785, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(236.9235, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(236.9235, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(552.9197, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(255.8522, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(255.8522, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(649.4821, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(327.6200, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(327.6200, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1677.9380, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(263.0069, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(263.0069, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(595.2731, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(257.0764, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(257.0764, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(481.1401, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(301.1214, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(301.1214, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(578.0968, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(350.3442, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(350.3442, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(557.8597, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(333.9577, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(333.9577, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(594.2926, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(363.3462, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(363.3462, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(580.0856, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(330.5437, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(330.5437, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(679.4313, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(324.4258, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(324.4258, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(643.7475, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(338.8238, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(338.8238, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(532.2369, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(334.9426, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(334.9426, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(604.2868, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(391.1418, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(391.1418, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(668.1245, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(415.2429, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(415.2429, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(593.1080, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(429.2810, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(429.2810, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(648.2585, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(412.0297, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(412.0297, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(608.2863, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(420.3894, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(420.3894, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2055.7146, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(392.4826, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(392.4826, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(632.8287, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(361.5146, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(361.5146, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(553.7527, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(474.2712, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(474.2712, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(508.8452, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(489.5466, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(489.5466, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(574.5519, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(436.8607, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(436.8607, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(518.9051, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(477.5704, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(477.5704, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(450.2515, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(480.1402, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(480.1402, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(435.8818, device='cuda:0', grad_fn=<MseLossBackward0>)
# Progress::   1%| ▎                                                  | 35:08
# tensor(474.4394, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(474.4394, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(436.1827, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(519.4886, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(519.4886, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(479.2360, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(400.7763, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(400.7763, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(389.6004, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(490.0496, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(490.0496, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(477.6417, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(506.7345, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(506.7345, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(438.6676, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(476.7858, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(476.7858, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(411.7036, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(455.5686, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(455.5686, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(419.0720, device='cuda:0', grad_fn=<MseLossBackward0>)
# Progress::   1%| ▍                                                  | 23:47
# tensor(464.9573, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(464.9573, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(442.1571, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(440.1808, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(440.1808, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(415.8162, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(510.4566, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(510.4566, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(467.8482, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(470.3777, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(470.3777, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(429.9060, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(504.9351, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(504.9351, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(486.9043, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(448.9961, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(448.9961, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(439.2570, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(488.8324, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(488.8324, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(418.8742, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(496.0938, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(496.0938, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(463.7790, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(506.2964, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(506.2964, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(411.9989, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(506.5662, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(506.5662, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(456.3817, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(471.4803, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(471.4803, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(428.9424, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(549.5492, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(549.5492, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(671.2762, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(515.3705, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(515.3705, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(450.0641, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(508.5578, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(508.5578, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(491.4411, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(558.8992, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(558.8992, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(594.0579, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(467.0905, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(467.0905, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(464.8150, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(574.4845, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(574.4845, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(711.7322, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(513.3025, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(513.3025, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(545.0664, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(460.3358, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(460.3358, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(496.1621, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(491.1263, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(491.1263, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(442.7139, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(505.8227, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(505.8227, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(493.6150, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(506.3968, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(506.3968, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(533.8236, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(481.8058, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(481.8058, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(495.0592, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(518.4223, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(518.4223, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(467.0906, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(527.7264, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(527.7264, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(510.5965, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(113598.7188, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(113598.7188, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(5017234., device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(5634.0205, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(5634.0205, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(229427.1562, device='cuda:0', grad_fn=<MseLossBackward0>)
# Progress::   1%| ▌                                                  | 23:58
# tensor(541.8591, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(541.8591, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(570.9827, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(544.1539, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(544.1539, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(618.4977, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(525.7694, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(525.7694, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(556.3141, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(556.4502, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(556.4502, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(515.7054, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(467.4415, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(467.4415, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(390.9475, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(478.7885, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(478.7885, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(392.7802, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(445.2636, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(445.2636, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(443.8438, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(470.7720, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(470.7720, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(435.6263, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(530.7498, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(530.7498, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(421.7532, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(505.3885, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(505.3885, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(391.9017, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(545.2773, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(545.2773, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(461.7078, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(517.2928, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(517.2928, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(380.9833, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(700.7913, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(700.7913, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(984.4883, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(524.8741, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(524.8741, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(528.6243, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(512.8333, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(512.8333, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(373.7034, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(637.5894, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(637.5894, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(796.3045, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(544.5289, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(544.5289, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(463.4789, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(546.3292, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(546.3292, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(544.5912, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(551.4248, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(551.4248, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(462.3659, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(571.7198, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(571.7198, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(491.9301, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(367.4537, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(367.4537, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(872.4542, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(516.4924, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(516.4924, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(455.3332, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(500.8832, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(500.8832, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(437.3087, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(543.9489, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(543.9489, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(463.1045, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(521.2269, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(521.2269, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(487.3035, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(534.0401, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(534.0401, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(487.7190, device='cuda:0', grad_fn=<MseLossBackward0>)
# Progress::   1%| ▌                                                  | 24:02
# tensor(503.5761, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(503.5761, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(458.4067, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(512.1500, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(512.1500, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(486.8539, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(489.0177, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(489.0177, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(470.7900, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(516.8380, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(516.8380, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(460.4981, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(507.0755, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(507.0755, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(436.3980, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(542.2526, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(542.2526, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(474.1639, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(491.0524, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(491.0524, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(426.5634, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(549.6750, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(549.6750, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(722.5095, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(517.1301, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(517.1301, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(460.4164, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(556.5468, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(556.5468, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(444.3561, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(504.2700, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(504.2700, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(464.8914, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(565.8861, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(565.8861, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(475.0373, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(547.4755, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(547.4755, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(487.5102, device='cuda:0', grad_fn=<MseLossBackward0>)
# Progress::   1%| ▋                                                  | 20:00
# tensor(578.4920, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(578.4920, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(463.2468, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(558.7815, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(558.7815, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(478.4511, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(559.2136, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(559.2136, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(494.4997, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(517.7163, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(517.7163, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(465.9193, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(513.8057, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(513.8057, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(430.8766, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(493.4651, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(493.4651, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(405.0703, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(479.3884, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(479.3884, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(446.2473, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(511.7313, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(511.7313, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(447.8546, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(526.9516, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(526.9516, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(492.3073, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(525.7469, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(525.7469, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(472.2353, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(506.1280, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(506.1280, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(439.1565, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(507.7084, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(507.7084, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(432.7899, device='cuda:0', grad_fn=<MseLossBackward0>)
# Progress::   2%| ▊                                                  | 17:03
# tensor(517.4819, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(517.4819, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(465.0294, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(497.2551, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(497.2551, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(443.6169, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(491.7406, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(491.7406, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(463.4173, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(550.0502, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(550.0502, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(448.8878, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(504.4747, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(504.4747, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(535.9002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(514.0562, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(514.0562, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(466.0493, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(504.5572, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(504.5572, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(390.1212, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(549.2288, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(549.2288, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(446.3452, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(524.1008, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(524.1008, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(439.4687, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(504.3003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(504.3003, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(432.3011, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(490.3405, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(490.3405, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(420.0949, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(520.6576, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(520.6576, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(393.4468, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(473.0981, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(473.0981, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(418.8624, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(523.7447, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(523.7447, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(435.3521, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(460.7498, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(460.7498, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(412.5886, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(534.6150, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(534.6150, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(473.1141, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(547.2198, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(547.2198, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(490.0289, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(518.4192, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(518.4192, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(528.6954, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(540.6081, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(540.6081, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(483.8728, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(564.4276, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(564.4276, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(485.8111, device='cuda:0', grad_fn=<MseLossBackward0>)
# Progress::   2%| ▉                                                  | 17:14
# tensor(555.7142, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(555.7142, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(500.0995, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(515.0723, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(515.0723, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(494.2882, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(484.3826, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(484.3826, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(444.9577, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(505.5539, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(505.5539, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(480.8463, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(555.3093, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(555.3093, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(497.8280, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(495.0029, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(495.0029, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(442.2389, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(515.9578, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(515.9578, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(657.7131, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(460.9793, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(460.9793, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(463.2724, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(501.0190, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(501.0190, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(431.7041, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(510.4625, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(510.4625, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(481.3798, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(501.9674, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(501.9674, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(535.1246, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(516.7329, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(516.7329, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(496.6031, device='cuda:0', grad_fn=<MseLossBackward0>)
# Progress::   2%| █                                                  | 15:35
# tensor(492.5056, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(492.5056, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(476.0187, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(498.6164, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(498.6164, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(450.7295, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(469.7268, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(469.7268, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(441.3803, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(532.5171, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(532.5171, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1149.9657, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(525.3077, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(525.3077, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(499.7628, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(487.5158, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(487.5158, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(443.9677, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(496.1389, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(496.1389, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(418.4007, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(520.7245, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(520.7245, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(482.9054, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(485.9074, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(485.9074, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(471.0695, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(488.2875, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(488.2875, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(461.0094, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(521.2899, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(521.2899, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(474.5833, device='cuda:0', grad_fn=<MseLossBackward0>)
#  Epoch 10, Loss: 5.002981662750244
# Progress::   2%| █                                                  | 25:48
# tensor(509.2125, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(509.2125, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(474.0943, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(532.8022, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(532.8022, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1113.3142, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(532.5469, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(532.5469, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(470.4449, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(493.6948, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(493.6948, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(420.7175, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(484.8402, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(484.8402, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(484.0568, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(508.4888, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(508.4888, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(505.9547, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(572.8759, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(572.8759, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(514.7546, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(510.6183, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(510.6183, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(500.2805, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(511.0053, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(511.0053, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(503.6573, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(547.1002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(547.1002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(519.8989, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(500.4166, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(500.4166, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(480.9120, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(523.2153, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(523.2153, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(454.4225, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(499.7957, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(499.7957, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(386.2830, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(549.6304, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(549.6304, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(567.4484, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(579.5331, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(579.5331, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(468.2691, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(523.8843, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(523.8843, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(380.4164, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(505.7986, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(505.7986, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(407.3698, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(522.7659, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(522.7659, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(385.3614, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(495.5126, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(495.5126, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(409.1703, device='cuda:0', grad_fn=<MseLossBackward0>)
# Progress::   2%| █▏                                                 | 23:26
# tensor(522.5477, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(522.5477, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(422.3052, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(526.0765, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(526.0765, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(439.6661, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(583.3673, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(583.3673, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(523.6697, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(538.3942, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(538.3942, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(450.3039, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(568.2405, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(568.2405, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(403.8671, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(524.8294, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(524.8294, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(480.1847, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(544.2026, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(544.2026, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(466.4477, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(497.3778, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(497.3778, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(457.4484, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(565.6715, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(565.6715, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(458.2684, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(531.5740, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(531.5740, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(441.3257, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(539.6790, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(539.6790, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(442.5920, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(515.4106, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(515.4106, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(453.4562, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(487.1873, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(487.1873, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(405.4785, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(469.8023, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(469.8023, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(404.3107, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(534.5299, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(534.5299, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(441.0513, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(513.7213, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(513.7213, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(437.3271, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2444.9648, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2444.9648, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(10729.9521, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(495.1036, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(495.1036, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(543.9184, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(534.5502, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(534.5502, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(459.3668, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(493.6684, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(493.6684, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(421.2954, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(514.8145, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(514.8145, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(465.1078, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(515.9059, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(515.9059, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(462.7892, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(511.3959, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(511.3959, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(420.6135, device='cuda:0', grad_fn=<MseLossBackward0>)
# Progress::   3%| █▎                                                 | 22:17
# tensor(566.1987, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(566.1987, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(450.8986, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(507.5717, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(507.5717, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(506.5521, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1599.5953, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1599.5953, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8317.4961, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(513.5091, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(513.5091, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(612.5964, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(488.7991, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(488.7991, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(419.7010, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(522.0858, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(522.0858, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(448.1028, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(463.2267, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(463.2267, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(443.8648, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(474.8157, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(474.8157, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(425.8102, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(538.9482, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(538.9482, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(528.1190, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(481.7335, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(481.7335, device='cuda:0', grad_fn=<MseLossBackward0>)
# ...
# tensor(202.0682, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(478.7069, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(478.7069, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(238.3802, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(483.0939, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(483.0939, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(215.9908, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(488.8231, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(488.8231, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(208.6914, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(515.6196, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(515.6196, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(199.1468, device='cuda:0', grad_fn=<MseLossBackward0>)
# Progress::   9%| ████▌                                              | 12:35
# tensor(525.0463, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(525.0463, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(214.3202, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(524.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(524.0075, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(194.6834, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(523.7929, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(523.7929, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(210.0570, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(500.4351, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(500.4351, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(324.4553, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(524.8529, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(524.8529, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(212.3665, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(528.9880, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(528.9880, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(209.2871, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(531.1118, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(531.1118, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(205.8865, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(485.2802, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(485.2802, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(197.1057, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(481.7654, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(481.7654, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(317.8023, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(515.1529, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(515.1529, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(200.0034, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(476.2561, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(476.2561, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(204.6872, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(477.6566, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(477.6566, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(199.9791, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(523.1334, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(523.1334, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(207.2318, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(498.7918, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(498.7918, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(203.9931, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(507.4481, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(507.4481, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(219.1577, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(491.6956, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(491.6956, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(234.7070, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(446.8847, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(446.8847, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(4266.7925, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(509.6809, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(509.6809, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(202.6146, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(523.6481, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(523.6481, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(206.8809, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(526.3586, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(526.3586, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(216.0990, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(505.2213, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(505.2213, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(204.7890, device='cuda:0', grad_fn=<MseLossBackward0>)
# Progress::   9%| ████▌                                              | 13:29
# tensor(497.7755, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(497.7755, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(202.8804, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(497.5250, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(497.5250, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(212.6942, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(465.7875, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(465.7875, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(3331.8425, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(509.8702, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(509.8702, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(211.6285, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(483.8659, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(483.8659, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(214.0497, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(497.1236, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(497.1236, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(201.7829, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(489.5183, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(489.5183, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(209.9805, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(507.1120, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(507.1120, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(198.3054, device='cuda:0', grad_fn=<MseLossBackward0>)
# Progress::   9%| ████▋                                              | 10:55
# tensor(465.1127, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(465.1127, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(203.4051, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(449.3808, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(449.3808, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(3737.3569, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(509.9658, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(509.9658, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(203.9203, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(500.6329, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(500.6329, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(210.2830, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(514.1364, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(514.1364, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(212.5083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(476.2562, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(476.2562, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(223.9654, device='cuda:0', grad_fn=<MseLossBackward0>)
# Progress::  10%| ████▊                                              | 09:07
# tensor(493.9077, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(493.9077, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(215.8401, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(540.2368, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(540.2368, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(216.5851, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(422.4694, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(422.4694, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(3467.8215, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(506.4823, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(506.4823, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(226.6056, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(497.8999, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(497.8999, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(216.6300, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(490.6699, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(490.6699, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(218.6017, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(511.9729, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(511.9729, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(200.6279, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(442.3368, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(442.3368, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(399.8997, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(478.7788, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(478.7788, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(197.6655, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(495.8221, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(495.8221, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(200.1432, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(487.6304, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(487.6304, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(207.2591, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(551.5547, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(551.5547, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(213.1739, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(479.5483, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(479.5483, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(206.5432, device='cuda:0', grad_fn=<MseLossBackward0>)
# Progress::  10%| ████▉                                              | 09:38
# tensor(454.1821, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(454.1821, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(201.5333, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(488.1771, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(488.1771, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(195.2564, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(509.7220, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(509.7220, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(202.0722, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(500.0999, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(500.0999, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(203.0292, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(499.0856, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(499.0856, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(198.3718, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(487.2041, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(487.2041, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(203.8305, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(511.7744, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(511.7744, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(208.1275, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(475.4570, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(475.4570, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(207.4114, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(490.3307, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(490.3307, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(206.9611, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(497.2209, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(497.2209, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(198.5070, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(545.0945, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(545.0945, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2635.8611, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(474.2432, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(474.2432, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(205.0198, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(475.5251, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(475.5251, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(203.3068, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(498.7522, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(498.7522, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(227.8651, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(517.6458, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(517.6458, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(207.1481, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(485.2525, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(485.2525, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(207.6442, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(489.9001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(489.9001, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(215.8525, device='cuda:0', grad_fn=<MseLossBackward0>)
# Progress::  10%| █████                                              | 10:43
# tensor(470.0185, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(470.0185, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(207.8127, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(481.5688, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(481.5688, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(216.7290, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(462.7502, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(462.7502, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(221.4210, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(487.0708, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(487.0708, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(215.8520, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(482.1844, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(482.1844, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(212.5716, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(516.2076, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(516.2076, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(216.6953, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(504.1871, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(504.1871, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(222.8152, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(488.6544, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(488.6544, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(213.1239, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(464.8476, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(464.8476, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(212.6986, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(456.5938, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(456.5938, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(223.2822, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(431.5186, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(431.5186, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(220.5201, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(492.5958, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(492.5958, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(227.1747, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(497.7557, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(497.7557, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(228.0441, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(461.0128, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(461.0128, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(206.7844, device='cuda:0', grad_fn=<MseLossBackward0>)
